# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
df.head(3)
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas     Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer    Whalen   JWHALEN  515.123.4444  17-SEP-03
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10

# %%
df.tail()
# Out:
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 45          136      Hazel  Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 46          137     Renske      Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 47          138    Stephen      Stiles   SSTILES  650.121.2034  26-OCT-05
# 48          139       John         Seo      JSEO  650.121.2019  12-FEB-06
# 49          140     Joshua       Patel    JPATEL  650.121.1834  06-APR-06
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 45  ST_CLERK    2200             -         122             50
# 46  ST_CLERK    3600             -         123             50
# 47  ST_CLERK    3200             -         123             50
# 48  ST_CLERK    2700             -         123             50
# 49  ST_CLERK    2500             -         123             50

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['EMPLOYEE_ID',
#  'FIRST_NAME',
#  'LAST_NAME',
#  'EMAIL',
#  'PHONE_NUMBER',
#  'HIRE_DATE',
#  'JOB_ID',
#  'SALARY',
#  'COMMISSION_PCT',
#  'MANAGER_ID',
#  'DEPARTMENT_ID']

# %%
df["FIRST_NAME"]
# Out:
# 0          Donald
# 1         Douglas
# 2        Jennifer
# 3         Michael
# 4             Pat
# 5           Susan
# 6         Hermann
# 7         Shelley
# 8         William
# 9          Steven
# 10          Neena
# 11            Lex
# 12      Alexander
# 13          Bruce
# 14          David
# 15          Valli
# 16          Diana
# 17          Nancy
# 18         Daniel
# 19           John
# 20         Ismael
# 21    Jose Manuel
# 22           Luis
# 23            Den
# 24      Alexander
# 25         Shelli
# 26          Sigal
# 27            Guy
# 28          Karen
# 29        Matthew
# 30           Adam
# 31          Payam
# 32         Shanta
# 33          Kevin
# 34          Julia
# 35          Irene
# 36          James
# 37         Steven
# 38          Laura
# 39          Mozhe
# 40          James
# 41             TJ
# 42          Jason
# 43        Michael
# 44             Ki
# 45          Hazel
# 46         Renske
# 47        Stephen
# 48           John
# 49         Joshua
# ...

# %%
type(df["FIRST_NAME"])
# Out:
# pandas.core.series.Series

# %%
df[["FIRST_NAME"]]
# Out:
#      FIRST_NAME
# 0        Donald
# 1       Douglas
# 2      Jennifer
# 3       Michael
# 4           Pat
# 5         Susan
# 6       Hermann
# 7       Shelley
# 8       William
# 9        Steven
# 10        Neena
# 11          Lex
# 12    Alexander
# 13        Bruce
# 14        David
# 15        Valli
# 16        Diana
# 17        Nancy
# 18       Daniel
# 19         John
# 20       Ismael
# 21  Jose Manuel
# 22         Luis
# 23          Den
# 24    Alexander
# 25       Shelli
# 26        Sigal
# 27          Guy
# 28        Karen
# 29      Matthew
# 30         Adam
# 31        Payam
# 32       Shanta
# 33        Kevin
# 34        Julia
# 35        Irene
# 36        James
# 37       Steven
# 38        Laura
# 39        Mozhe
# 40        James
# 41           TJ
# 42        Jason
# 43      Michael
# 44           Ki
# 45        Hazel
# 46       Renske
# 47      Stephen
# 48         John
# 49       Joshua

# %%
type(df[["FIRST_NAME"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["FIRST_NAME", "LAST_NAME"]]
# Out:
#      FIRST_NAME    LAST_NAME
# 0        Donald     OConnell
# 1       Douglas        Grant
# 2      Jennifer       Whalen
# 3       Michael    Hartstein
# 4           Pat          Fay
# 5         Susan       Mavris
# 6       Hermann         Baer
# 7       Shelley      Higgins
# 8       William        Gietz
# 9        Steven         King
# 10        Neena      Kochhar
# 11          Lex      De Haan
# 12    Alexander       Hunold
# 13        Bruce        Ernst
# 14        David       Austin
# 15        Valli    Pataballa
# 16        Diana      Lorentz
# 17        Nancy    Greenberg
# 18       Daniel       Faviet
# 19         John         Chen
# 20       Ismael      Sciarra
# 21  Jose Manuel        Urman
# 22         Luis         Popp
# 23          Den     Raphaely
# 24    Alexander         Khoo
# 25       Shelli        Baida
# 26        Sigal       Tobias
# 27          Guy       Himuro
# 28        Karen   Colmenares
# 29      Matthew        Weiss
# 30         Adam        Fripp
# ...

# %%
df.dtypes
# Out:
# EMPLOYEE_ID        int64
# FIRST_NAME        object
# LAST_NAME         object
# EMAIL             object
# PHONE_NUMBER      object
# HIRE_DATE         object
# JOB_ID            object
# SALARY             int64
# COMMISSION_PCT    object
# MANAGER_ID        object
# DEPARTMENT_ID      int64
# dtype: object

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel("Financial.xlsx")
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df1 = pd.read_excel("Financial.xlsx")

# %%
df1.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
df1[["Country","Units Sold","Profit"]]
# Out:
#                       Country  Units Sold    Profit
# 0                      Canada      1618.5  16185.00
# 1                     Germany      1321.0  13210.00
# 2                      France      2178.0  10890.00
# 3                     Germany       888.0   4440.00
# 4                      Mexico      2470.0  12350.00
# ..                        ...         ...       ...
# 695                    France      2475.0  12375.00
# 696                    Mexico       546.0   2730.00
# 697                    Mexico      1368.0   1299.60
# 698                    Canada       723.0    686.85
# 699  United States of America      1806.0  13003.20
#
# [700 rows x 3 columns]

# %%
pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Faiz = pd.read_html("https://gist.githubusercontent.com/")

# %%
Faiz
# Out:
# [    0                                             1
#  0 NaN                             #!/usr/bin/python
#  1 NaN                       # -*- coding: utf-8 -*-
#  2 NaN                                   import glob
#  3 NaN                                     import os
#  4 NaN                             import subprocess
#  5 NaN                                    import sys
#  6 NaN  sys.path.append('/usr/local/munki/munkilib')
#  7 NaN                        import FoundationPlist
#  8 NaN                                           NaN
#  9 NaN  path = '/Users/abanks/Library/AutoPkg/Cache',
#      0                                                  1
#  0 NaN                                                 //
#  1 NaN                                                 //
#  2 NaN                                   // Adapted from:
#  3 NaN                                                 //
#  4 NaN  // Original: https://gist.github.com/loudmouth...
# ...

# %%
df2=pd.read_html("https://www.basketball-reference.com/leaders/ws_yearly.html")

# %%
df2
# Out:
# [     Season   Lg         Player     WS   Tm
#  0   2023-24  NBA   Nikola Jokić  12.98  DEN
#  1   2022-23  NBA   Nikola Jokić  14.93  DEN
#  2   2021-22  NBA   Nikola Jokić  15.24  DEN
#  3   2020-21  NBA   Nikola Jokić  15.62  DEN
#  4   2019-20  NBA   James Harden  13.12  HOU
#  ..      ...  ...            ...    ...  ...
#  82  1950-51  NBA  George Mikan*  23.43  MNL
#  83  1949-50  NBA  George Mikan*  21.13  MNL
#  84  1948-49  BAA  George Mikan*  20.86  MNL
#  85  1947-48  BAA    Bob Feerick  10.52  WSC
#  86  1946-47  BAA    Bob Feerick  18.59  WSC
#
#  [87 rows x 5 columns]]

# %%
type(df2)
# Out:
# list

# %%
len(df2)
# Out:
# 1

# %%
df3 =df2[0]

# %%
df3
# Out:
#      Season   Lg         Player     WS   Tm
# 0   2023-24  NBA   Nikola Jokić  12.98  DEN
# 1   2022-23  NBA   Nikola Jokić  14.93  DEN
# 2   2021-22  NBA   Nikola Jokić  15.24  DEN
# 3   2020-21  NBA   Nikola Jokić  15.62  DEN
# 4   2019-20  NBA   James Harden  13.12  HOU
# ..      ...  ...            ...    ...  ...
# 82  1950-51  NBA  George Mikan*  23.43  MNL
# 83  1949-50  NBA  George Mikan*  21.13  MNL
# 84  1948-49  BAA  George Mikan*  20.86  MNL
# 85  1947-48  BAA    Bob Feerick  10.52  WSC
# 86  1946-47  BAA    Bob Feerick  18.59  WSC
#
# [87 rows x 5 columns]

# %%
df3.columns
# Out:
# Index(['Season', 'Lg', 'Player', 'WS', 'Tm'], dtype='object')

# %%
df3.tail()
# Out:
#      Season   Lg         Player     WS   Tm
# 82  1950-51  NBA  George Mikan*  23.43  MNL
# 83  1949-50  NBA  George Mikan*  21.13  MNL
# 84  1948-49  BAA  George Mikan*  20.86  MNL
# 85  1947-48  BAA    Bob Feerick  10.52  WSC
# 86  1946-47  BAA    Bob Feerick  18.59  WSC

# %%
df3.to_csv("player_data.csv",index=False)
