# %%
import pandas as pd

# %%
df1 =pd.read_csv('nucc_taxonomy_231.csv')

# %%
df1
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...

# %%
df1.columns
# Out:
# Index(['Code', 'Grouping', 'Classification', 'Specialization', 'Definition',
#        'Notes', 'Display Name', 'Section', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df1[['Code','Grouping','Display Name']]
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                                           Display Name
# 0                                Multi-Specialty Group
# 1                               Single Specialty Group
# 2                       Allergy & Immunology Physician
# 3                                    Allergy Physician
# ...

# %%
df1.dropna() #delete NA row
# Out:
# Empty DataFrame
# Columns: [Code, Grouping, Classification, Specialization, Definition, Notes, Display Name, Section, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12]
# Index: []

# %%
df1
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#      index        Code                             Grouping  \
# 0        0  193200000X                                Group
# 1        1  193400000X                                Group
# 2        2  207K00000X  Allopathic & Osteopathic Physicians
# 3        3  207KA0200X  Allopathic & Osteopathic Physicians
# 4        4  207KI0005X  Allopathic & Osteopathic Physicians
# ..     ...         ...                                  ...
# 869    869  343800000X              Transportation Services
# 870    870  344600000X              Transportation Services
# 871    871  347D00000X              Transportation Services
# 872    872  347E00000X              Transportation Services
# 873    873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# ...

# %%
g = df1.groupby('Code') #it data in group

# %%
g

# %%
g.sum() #sum
# Out:
#             index                                      Grouping  \
# Code
# 101200000X    244  Behavioral Health & Social Service Providers
# 101Y00000X    238  Behavioral Health & Social Service Providers
# 101YA0400X    239  Behavioral Health & Social Service Providers
# 101YM0800X    240  Behavioral Health & Social Service Providers
# 101YP1600X    241  Behavioral Health & Social Service Providers
# ...           ...                                           ...
# 385HR2055X    823                         Respite Care Facility
# 385HR2060X    824                         Respite Care Facility
# 385HR2065X    825                         Respite Care Facility
# 390200000X    623                          Student, Health Care
# 405300000X    437                       Other Service Providers
#
#                                                Classification  \
# Code
# 101200000X                                    Drama Therapist
# ...

# %%
#g.mean() #average

# %%
g.max().transpose() #transpose row and columns.
# Out:
# Code                                                   101200000X  \
# index                                                         244
# Grouping             Behavioral Health & Social Service Providers
# Classification                                    Drama Therapist
# Specialization                                                NaN
# Definition      Drama therapists are trained in the intentiona...
# Notes           Source:  North American Drama Therapy Associat...
# Display Name                                      Drama Therapist
# Section                                                Individual
# Unnamed: 8                                                    NaN
# Unnamed: 9                                                    NaN
# Unnamed: 10                                                   NaN
# Unnamed: 11                                                   NaN
# Unnamed: 12                                                   NaN
#
# ...

# %%
df1
# Out:
#      index        Code                             Grouping  \
# 0        0  193200000X                                Group
# 1        1  193400000X                                Group
# 2        2  207K00000X  Allopathic & Osteopathic Physicians
# 3        3  207KA0200X  Allopathic & Osteopathic Physicians
# 4        4  207KI0005X  Allopathic & Osteopathic Physicians
# ..     ...         ...                                  ...
# 869    869  343800000X              Transportation Services
# 870    870  344600000X              Transportation Services
# 871    871  347D00000X              Transportation Services
# 872    872  347E00000X              Transportation Services
# 873    873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# ...

# %%
df5=df1[['Display Name','Notes','Grouping']][0:5]

# %%
df4=df1[['Display Name','Notes','Grouping']][5:10]

# %%
df5
# Out:
#                                         Display Name  \
# 0                              Multi-Specialty Group
# 1                             Single Specialty Group
# 2                     Allergy & Immunology Physician
# 3                                  Allergy Physician
# 4  Clinical & Laboratory Immunology (Allergy & Im...
#
#                                                Notes  \
# 0                                    [7/1/2003: new]
# 1                                    [7/1/2003: new]
# 2  Source: American Board of Medical Specialties,...
# 3           Source: National Uniform Claim Committee
# 4  Source: National Uniform Claim Committee, 2022...
#
#                               Grouping
# 0                                Group
# 1                                Group
# 2  Allopathic & Osteopathic Physicians
# 3  Allopathic & Osteopathic Physicians
# 4  Allopathic & Osteopathic Physicians

# %%
df4
# Out:
#                                         Display Name  \
# 5                           Anesthesiology Physician
# 6      Addiction Medicine (Anesthesiology) Physician
# 7  Critical Care Medicine (Anesthesiology) Physician
# 8  Hospice and Palliative Medicine (Anesthesiolog...
# 9           Pain Medicine (Anesthesiology) Physician
#
#                                                Notes  \
# 5  Source: American Board of Medical Specialties,...
# 6  Source: National Uniform Claim Committee, 2009...
# 7  Source: American Board of Medical Specialties,...
# 8  Source: American Academy of Hospice and Pallia...
# 9  Source: American Board of Medical Specialties,...
#
#                               Grouping
# 5  Allopathic & Osteopathic Physicians
# 6  Allopathic & Osteopathic Physicians
# 7  Allopathic & Osteopathic Physicians
# 8  Allopathic & Osteopathic Physicians
# 9  Allopathic & Osteopathic Physicians

# %%
#merge the data(vertical & horizontally)

# %%
df6 = pd.concat([df5,df4])

# %%
df7 = pd.concat([df5,df4],axis=1)

# %%
df6
# Out:
#                                         Display Name  \
# 0                              Multi-Specialty Group
# 1                             Single Specialty Group
# 2                     Allergy & Immunology Physician
# 3                                  Allergy Physician
# 4  Clinical & Laboratory Immunology (Allergy & Im...
# 5                           Anesthesiology Physician
# 6      Addiction Medicine (Anesthesiology) Physician
# 7  Critical Care Medicine (Anesthesiology) Physician
# 8  Hospice and Palliative Medicine (Anesthesiolog...
# 9           Pain Medicine (Anesthesiology) Physician
#
#                                                Notes  \
# 0                                    [7/1/2003: new]
# 1                                    [7/1/2003: new]
# 2  Source: American Board of Medical Specialties,...
# 3           Source: National Uniform Claim Committee
# 4  Source: National Uniform Claim Committee, 2022...
# 5  Source: American Board of Medical Specialties,...
# ...

# %%
df7
# Out:
#                                         Display Name  \
# 0                              Multi-Specialty Group
# 1                             Single Specialty Group
# 2                     Allergy & Immunology Physician
# 3                                  Allergy Physician
# 4  Clinical & Laboratory Immunology (Allergy & Im...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                                Notes  \
# 0                                    [7/1/2003: new]
# 1                                    [7/1/2003: new]
# 2  Source: American Board of Medical Specialties,...
# 3           Source: National Uniform Claim Committee
# 4  Source: National Uniform Claim Committee, 2022...
# 5                                                NaN
# ...

# %%
df7.fillna("Abhi") #fill the data in na
# Out:
#                                         Display Name  \
# 0                              Multi-Specialty Group
# 1                             Single Specialty Group
# 2                     Allergy & Immunology Physician
# 3                                  Allergy Physician
# 4  Clinical & Laboratory Immunology (Allergy & Im...
# 5                                               Abhi
# 6                                               Abhi
# 7                                               Abhi
# 8                                               Abhi
# 9                                               Abhi
#
#                                                Notes  \
# 0                                    [7/1/2003: new]
# 1                                    [7/1/2003: new]
# 2  Source: American Board of Medical Specialties,...
# 3           Source: National Uniform Claim Committee
# 4  Source: National Uniform Claim Committee, 2022...
# 5                                               Abhi
# ...

# %%
#pd.merge(data1,data2) this is merge into row and column like matrix(comman data show)

# %%
#pd.merge(data1,data2, how ='left') working from left

# %%
#pd.merge(data1,data2, how ='cross') working crossing the data(combination of all)
